# %% [markdown]
# # 日本語平文と韻律記号付き音素列のペアデータの生成
#
# CSJ書き起こしの平文（TRNのForm2）の各文に対してESPnetの前処理（PyOpenJTalkを用いた韻律記号付き音素列）を適用した結果をJSONファイル（all.json）に保存する

# %%
# CSJ の TRN ファイルがあるディレクトリ
CSJ_TRN_DIR = "/autofs/diamond/share/corpus/CSJ/TRN/Form2"

# %%
import os

# TRNファイルのリストを作成
trn_files = []
for root, dirs, files in os.walk(CSJ_TRN_DIR):
    for file in files:
        if file.endswith('.trn'):
            trn_files.append(os.path.join(root, file))

# %%
from csj_formatter import remove_tag_from_plain_tagged_string
from espnet_phoneme_tokenizer import pyopenjtalk_g2p_prosody

def read_and_format_trn_file(filename):
    # 講演ID
    session_id = os.path.basename(filename).split('.')[0]

    results = []
    with open(filename, 'r', encoding='sjis') as f:
        for line in f:
            utt_id, _, text = line.rstrip().split(' ', 2)
            channel = text[0]
            text = text[2:]

            if 'R' in text:
                continue
            if '<' in text:
                continue

            try:
                formatted_text = remove_tag_from_plain_tagged_string(text)
            except ValueError as e:
                # print(e)
                # print(text)
                continue

            if len(formatted_text) == 0:
                continue

            phoneme_text = ' '.join(pyopenjtalk_g2p_prosody(formatted_text))

            if len(phoneme_text) == 0:
                continue
            
            results.append({
                'session_id': session_id,
                'utt_id': int(utt_id),
                'channel': channel,
                'text': formatted_text,
                'phoneme_text': phoneme_text,
            })
            
        return results

# %%
import tqdm

results = []
for filename in tqdm.tqdm(trn_files):
    results.extend(read_and_format_trn_file(filename))
# Out:
#   0%|          | 2/3302 [00:00<03:11, 17.26it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#   1%|          | 19/3302 [00:00<02:46, 19.69it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#   1%|          | 22/3302 [00:01<02:43, 20.03it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#   1%|          | 28/3302 [00:01<02:35, 21.07it/s]WARNING: JPCommonLabel_insert_pause() in jpcommon_label.c: First mora should not be short pause.
# WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#   1%|          | 31/3302 [00:01<02:42, 20.11it/s]WARNING: JPCommonLabel_insert_pause() in jpcommon_label.c: First mora should not be short pause.
# WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#   1%|          | 36/3302 [00:02<03:41, 14.78it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#   1%|          | 38/3302 [00:02<03:45, 14.45it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#   1%|          | 40/3302 [00:02<03:44, 14.50it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#   2%|▏         | 60/3302 [00:03<03:36, 14.98it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
# WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
# WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#   2%|▏         | 64/3302 [00:03<03:31, 15.30it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
# WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#   2%|▏         | 66/3302 [00:04<03:36, 14.98it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#   2%|▏         | 82/3302 [00:04<02:29, 21.52it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#   3%|▎         | 88/3302 [00:05<02:25, 22.06it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#   6%|▌         | 206/3302 [00:10<02:24, 21.42it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#  10%|▉         | 315/3302 [00:16<02:21, 21.05it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#  10%|▉         | 318/3302 [00:16<02:23, 20.75it/s]WARNING: JPCommonLabel_insert_pause() in jpcommon_label.c: First mora should not be short pause.
# WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#  10%|█         | 336/3302 [00:17<02:52, 17.19it/s]WARNING: NJDNode_set_acc() in njd_node.c: Accent must be positive value.
#  10%|█         | 342/3302 [00:17<03:08, 15.70it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#  10%|█         | 344/3302 [00:18<03:02, 16.21it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#  11%|█         | 360/3302 [00:19<03:24, 14.35it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#  11%|█         | 364/3302 [00:19<03:47, 12.93it/s]WARNING: JPCommonLabel_insert_pause() in jpcommon_label.c: First mora should not be short pause.
#  15%|█▍        | 492/3302 [00:25<02:01, 23.11it/s]WARNING: JPCommonLabel_insert_pause() in jpcommon_label.c: First mora should not be short pause.
#  16%|█▌        | 528/3302 [00:26<02:25, 19.12it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#  16%|█▌        | 532/3302 [00:27<02:50, 16.29it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#  16%|█▋        | 537/3302 [00:27<02:34, 17.90it/s]WARNING: JPCommonLabel_insert_pause() in jpcommon_label.c: First mora should not be short pause.
#  16%|█▋        | 541/3302 [00:27<02:54, 15.80it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#  16%|█▋        | 543/3302 [00:27<02:48, 16.38it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#  17%|█▋        | 553/3302 [00:28<02:49, 16.20it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#
/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#  73%|███████▎  | 2414/3302 [02:40<01:06, 13.37it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#  73%|███████▎  | 2424/3302 [02:41<01:08, 12.80it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#  74%|███████▎  | 2428/3302 [02:41<01:06, 13.15it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#  74%|███████▎  | 2432/3302 [02:41<01:02, 13.83it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#  75%|███████▌  | 2484/3302 [02:45<00:57, 14.28it/s]WARNING: JPCommonLabel_insert_pause() in jpcommon_label.c: First mora should not be short pause.
#  75%|███████▌  | 2486/3302 [02:45<00:56, 14.37it/s]WARNING: JPCommonLabel_insert_pause() in jpcommon_label.c: First mora should not be short pause.
#  76%|███████▋  | 2524/3302 [02:47<00:48, 16.00it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#  77%|███████▋  | 2556/3302 [02:50<01:35,  7.80it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#  78%|███████▊  | 2566/3302 [02:51<01:11, 10.36it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#  79%|███████▊  | 2594/3302 [02:53<00:55, 12.72it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#  79%|███████▊  | 2596/3302 [02:54<01:00, 11.64it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#  79%|███████▉  | 2605/3302 [02:54<00:48, 14.24it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#  79%|███████▉  | 2607/3302 [02:55<01:21,  8.51it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#  79%|███████▉  | 2611/3302 [02:55<01:08, 10.08it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#  79%|███████▉  | 2620/3302 [02:56<00:55, 12.31it/s]WARNING: JPCommonLabel_insert_pause() in jpcommon_label.c: First mora should not be short pause.
#  80%|███████▉  | 2641/3302 [02:57<00:42, 15.47it/s]WARNING: NJDNode_set_acc() in njd_node.c: Accent must be positive value.
#  81%|████████  | 2661/3302 [02:59<00:54, 11.74it/s]WARNING: JPCommonLabel_insert_pause() in jpcommon_label.c: First mora should not be short pause.
#  82%|████████▏ | 2699/3302 [03:02<00:39, 15.25it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#  83%|████████▎ | 2730/3302 [03:04<00:45, 12.47it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#  83%|████████▎ | 2732/3302 [03:04<00:45, 12.63it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#  83%|████████▎ | 2736/3302 [03:05<00:53, 10.58it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#  83%|████████▎ | 2748/3302 [03:06<00:39, 13.97it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#  83%|████████▎ | 2750/3302 [03:06<00:40, 13.67it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#  84%|████████▎ | 2758/3302 [03:07<00:54, 10.02it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#  84%|████████▍ | 2771/3302 [03:07<00:35, 14.85it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#  88%|████████▊ | 2908/3302 [03:17<00:27, 14.37it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#  89%|████████▉ | 2933/3302 [03:19<00:24, 14.79it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
# WARNING: JPCommonLabel_insert_pause() in jpcommon_label.c: First mora should not be short pause.
#  91%|█████████ | 3005/3302 [03:25<00:20, 14.21it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#  92%|█████████▏| 3028/3302 [03:27<00:25, 10.61it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
# WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#  93%|█████████▎| 3057/3302 [03:29<00:21, 11.63it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#  94%|█████████▎| 3095/3302 [03:32<00:13, 14.85it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#  94%|█████████▍| 3111/3302 [03:33<00:12, 14.75it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
# WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#  94%|█████████▍| 3113/3302 [03:33<00:12, 15.13it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#  95%|█████████▍| 3133/3302 [03:35<00:12, 13.93it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#  95%|█████████▌| 3138/3302 [03:35<00:10, 15.50it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#  96%|█████████▌| 3174/3302 [03:38<00:10, 12.59it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#  96%|█████████▋| 3185/3302 [03:39<00:09, 12.69it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#  97%|█████████▋| 3189/3302 [03:39<00:07, 14.26it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#  98%|█████████▊| 3223/3302 [03:41<00:05, 13.90it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
# WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#  98%|█████████▊| 3231/3302 [03:42<00:05, 12.31it/s]WARNING: JPCommonLabel_insert_pause() in jpcommon_label.c: First mora should not be short pause.
#  98%|█████████▊| 3240/3302 [03:43<00:04, 13.36it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
# WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#  98%|█████████▊| 3244/3302 [03:43<00:03, 14.86it/s]WARNING: NJDNode_set_acc() in njd_node.c: Accent must be positive value.
# WARNING: NJDNode_set_acc() in njd_node.c: Accent must be positive value.
#  99%|█████████▊| 3259/3302 [03:44<00:03, 12.78it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
#  99%|█████████▉| 3271/3302 [03:45<00:03,  7.98it/s]WARNING: convert_pos() in njd2jpcommon.c: 記号 固有名詞 組織 * are not appropriate POS.
# 100%|██████████| 3302/3302 [03:48<00:00, 14.46it/s]

# %%
import json
json.dump(results, open('all.json', 'w', encoding='utf-8'), ensure_ascii=False)
